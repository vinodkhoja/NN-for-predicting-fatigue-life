# %%
import numpy as np
 
import os

# %%
#os.chdir("../input")
import pandas as pd
data = pd.read_csv("T351_aluminium_data_true.csv")
data[0:5]
# Out:
#      R  delta_K  crack_growth_rate
# 0  0.0  3.31514       5.040000e-07
# 1  0.0  3.36765       8.930000e-07
# 2  0.0  3.44451       1.010000e-06
# 3  0.0  3.52313       1.190000e-06
# 4  0.0  3.61371       1.730000e-06

# %%
original_data = pd.read_csv("T351_aluminium_data_true.csv")

# %%
data.shape
# Out:
# (77, 3)

# %%
data["crack_growth_rate"] = (10**(5) ) * data["crack_growth_rate"]

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
# Out:
# Using TensorFlow backend.

# %%
from keras.models import model_from_json

# %%
x=data.drop(['crack_growth_rate'],axis=1)
y=data.drop(['R','delta_K'],axis=1)
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
#changing the training data9training only on R(0.1,0.3,0.5)
train_data = data.loc[data['R']!=0.1]
X_train = train_data.drop(['crack_growth_rate'],axis = 1)
y_train = train_data.drop(['R','delta_K'],axis = 1)
test_data = data.loc[data['R']==0.1]
X_test = test_data.drop(['crack_growth_rate'],axis = 1)
y_test = test_data.drop(['R','delta_K'],axis = 1)

# %%
X_train.shape[0]
# Out:
# 55

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\vinod khoja\AppData\Local\conda\conda\envs\keras-gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 165,249
# Trainable params: 165,249
# Non-trainable params: 0
# _________________________________________________________________

# %%
NN_model.fit(X_train,y_train, epochs=1000, batch_size=32, validation_split = 0.15)
# Out:
# WARNING:tensorflow:From C:\Users\vinod khoja\AppData\Local\conda\conda\envs\keras-gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 46 samples, validate on 9 samples
# Epoch 1/1000
# 46/46 [==============================] - 4s 80ms/step - loss: 3.8391 - mean_absolute_error: 3.8391 - val_loss: 2.2207 - val_mean_absolute_error: 2.2207
# Epoch 2/1000
# 46/46 [==============================] - 0s 434us/step - loss: 3.6957 - mean_absolute_error: 3.6957 - val_loss: 2.0221 - val_mean_absolute_error: 2.0221
# Epoch 3/1000
# 46/46 [==============================] - 0s 564us/step - loss: 3.7426 - mean_absolute_error: 3.7426 - val_loss: 1.9967 - val_mean_absolute_error: 1.9967
# Epoch 4/1000
# 46/46 [==============================] - 0s 499us/step - loss: 3.7283 - mean_absolute_error: 3.7283 - val_loss: 2.0733 - val_mean_absolute_error: 2.0733
# Epoch 5/1000
# 46/46 [==============================] - 0s 455us/step - loss: 3.6966 - mean_absolute_error: 3.6966 - val_loss: 2.2268 - val_mean_absolute_error: 2.2268
# Epoch 6/1000
# 46/46 [==============================] - 0s 585us/step - loss: 3.6870 - mean_absolute_error: 3.6870 - val_loss: 2.3545 - val_mean_absolute_error: 2.3545
# Epoch 7/1000
# 46/46 [==============================] - 0s 564us/step - loss: 3.6888 - mean_absolute_error: 3.6888 - val_loss: 2.3057 - val_mean_absolute_error: 2.3057
# Epoch 8/1000
# 46/46 [==============================] - 0s 498us/step - loss: 3.6734 - mean_absolute_error: 3.6734 - val_loss: 2.2259 - val_mean_absolute_error: 2.2259
# Epoch 9/1000
# 46/46 [==============================] - 0s 542us/step - loss: 3.6554 - mean_absolute_error: 3.6554 - val_loss: 2.1222 - val_mean_absolute_error: 2.1222
# Epoch 10/1000
# 46/46 [==============================] - 0s 499us/step - loss: 3.6690 - mean_absolute_error: 3.6690 - val_loss: 2.0399 - val_mean_absolute_error: 2.0399
# Epoch 11/1000
# 46/46 [==============================] - 0s 607us/step - loss: 3.6696 - mean_absolute_error: 3.6696 - val_loss: 2.0481 - val_mean_absolute_error: 2.0481
# Epoch 12/1000
# 46/46 [==============================] - 0s 564us/step - loss: 3.6533 - mean_absolute_error: 3.6533 - val_loss: 2.1182 - val_mean_absolute_error: 2.1182
# Epoch 13/1000
# 46/46 [==============================] - 0s 694us/step - loss: 3.6418 - mean_absolute_error: 3.6418 - val_loss: 2.2410 - val_mean_absolute_error: 2.2410
# Epoch 14/1000
# 46/46 [==============================] - 0s 499us/step - loss: 3.6214 - mean_absolute_error: 3.6214 - val_loss: 2.2748 - val_mean_absolute_error: 2.2748
# Epoch 15/1000
# 46/46 [==============================] - 0s 716us/step - loss: 3.6119 - mean_absolute_error: 3.6119 - val_loss: 2.2249 - val_mean_absolute_error: 2.2249
# Epoch 16/1000
# 46/46 [==============================] - 0s 455us/step - loss: 3.5888 - mean_absolute_error: 3.5888 - val_loss: 2.1754 - val_mean_absolute_error: 2.1754
# Epoch 17/1000
# 46/46 [==============================] - 0s 434us/step - loss: 3.5636 - mean_absolute_error: 3.5636 - val_loss: 2.1349 - val_mean_absolute_error: 2.1349
# Epoch 18/1000
# 46/46 [==============================] - 0s 412us/step - loss: 3.5327 - mean_absolute_error: 3.5327 - val_loss: 2.1580 - val_mean_absolute_error: 2.1580
# Epoch 19/1000
# 46/46 [==============================] - 0s 542us/step - loss: 3.4852 - mean_absolute_error: 3.4852 - val_loss: 2.2379 - val_mean_absolute_error: 2.2379
# Epoch 20/1000
# 46/46 [==============================] - 0s 433us/step - loss: 3.4346 - mean_absolute_error: 3.4346 - val_loss: 1.9174 - val_mean_absolute_error: 1.9174
# Epoch 21/1000
# 46/46 [==============================] - 0s 477us/step - loss: 3.4112 - mean_absolute_error: 3.4112 - val_loss: 1.9950 - val_mean_absolute_error: 1.9950
# Epoch 22/1000
# 46/46 [==============================] - 0s 607us/step - loss: 3.3440 - mean_absolute_error: 3.3440 - val_loss: 2.0348 - val_mean_absolute_error: 2.0348
# Epoch 23/1000
# 46/46 [==============================] - ETA: 0s - loss: 2.8912 - mean_absolute_error: 2.891 - 0s 629us/step - loss: 3.2235 - mean_absolute_error: 3.2235 - val_loss: 1.7371 - val_mean_absolute_error: 1.7371
# Epoch 24/1000
# 46/46 [==============================] - 0s 564us/step - loss: 3.2733 - mean_absolute_error: 3.2733 - val_loss: 1.7649 - val_mean_absolute_error: 1.7649
# Epoch 25/1000
# 46/46 [==============================] - 0s 499us/step - loss: 3.0896 - mean_absolute_error: 3.0896 - val_loss: 1.9455 - val_mean_absolute_error: 1.9455
# Epoch 26/1000
# 46/46 [==============================] - 0s 563us/step - loss: 3.0151 - mean_absolute_error: 3.0151 - val_loss: 1.5962 - val_mean_absolute_error: 1.5962
# Epoch 27/1000
# 46/46 [==============================] - 0s 542us/step - loss: 3.0165 - mean_absolute_error: 3.0165 - val_loss: 1.5167 - val_mean_absolute_error: 1.5167
# Epoch 28/1000
# 46/46 [==============================] - 0s 477us/step - loss: 2.8311 - mean_absolute_error: 2.8311 - val_loss: 1.9322 - val_mean_absolute_error: 1.9322
# Epoch 29/1000
# 46/46 [==============================] - 0s 454us/step - loss: 2.7571 - mean_absolute_error: 2.7571 - val_loss: 1.3940 - val_mean_absolute_error: 1.3940
# Epoch 30/1000
# 46/46 [==============================] - 0s 434us/step - loss: 2.6500 - mean_absolute_error: 2.6500 - val_loss: 1.4338 - val_mean_absolute_error: 1.4338
# Epoch 31/1000
# 46/46 [==============================] - 0s 542us/step - loss: 2.6646 - mean_absolute_error: 2.6646 - val_loss: 1.4807 - val_mean_absolute_error: 1.4807
# Epoch 32/1000
# 46/46 [==============================] - 0s 672us/step - loss: 2.5086 - mean_absolute_error: 2.5086 - val_loss: 2.1870 - val_mean_absolute_error: 2.1870
# Epoch 33/1000
# 46/46 [==============================] - 0s 585us/step - loss: 2.5218 - mean_absolute_error: 2.5218 - val_loss: 1.1517 - val_mean_absolute_error: 1.1517
# Epoch 34/1000
# 46/46 [==============================] - 0s 477us/step - loss: 2.3955 - mean_absolute_error: 2.3955 - val_loss: 1.2509 - val_mean_absolute_error: 1.2509
# Epoch 35/1000
# 46/46 [==============================] - 0s 499us/step - loss: 2.3316 - mean_absolute_error: 2.3316 - val_loss: 2.1395 - val_mean_absolute_error: 2.1395
# Epoch 36/1000
# 46/46 [==============================] - 0s 672us/step - loss: 2.3792 - mean_absolute_error: 2.3792 - val_loss: 2.6465 - val_mean_absolute_error: 2.6465
# Epoch 37/1000
# 46/46 [==============================] - 0s 564us/step - loss: 2.8502 - mean_absolute_error: 2.8502 - val_loss: 1.8970 - val_mean_absolute_error: 1.8970
# Epoch 38/1000
# 46/46 [==============================] - 0s 412us/step - loss: 2.1429 - mean_absolute_error: 2.1429 - val_loss: 1.3001 - val_mean_absolute_error: 1.3001
# Epoch 39/1000
# 46/46 [==============================] - 0s 369us/step - loss: 2.2643 - mean_absolute_error: 2.2643 - val_loss: 1.0903 - val_mean_absolute_error: 1.0903
# Epoch 40/1000
# 46/46 [==============================] - 0s 390us/step - loss: 2.1237 - mean_absolute_error: 2.1237 - val_loss: 1.6734 - val_mean_absolute_error: 1.6734
# Epoch 41/1000
# 46/46 [==============================] - 0s 585us/step - loss: 1.8771 - mean_absolute_error: 1.8771 - val_loss: 1.7579 - val_mean_absolute_error: 1.7579
# Epoch 42/1000
# 46/46 [==============================] - 0s 499us/step - loss: 1.9249 - mean_absolute_error: 1.9249 - val_loss: 1.5540 - val_mean_absolute_error: 1.5540
# Epoch 43/1000
# 46/46 [==============================] - 0s 564us/step - loss: 1.7273 - mean_absolute_error: 1.7273 - val_loss: 1.2051 - val_mean_absolute_error: 1.2051
# Epoch 44/1000
# 46/46 [==============================] - 0s 542us/step - loss: 1.6737 - mean_absolute_error: 1.6737 - val_loss: 0.8935 - val_mean_absolute_error: 0.8935
# Epoch 45/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.8234 - mean_absolute_error: 1.8234 - val_loss: 1.7558 - val_mean_absolute_error: 1.7558
# Epoch 46/1000
# 46/46 [==============================] - 0s 520us/step - loss: 1.5552 - mean_absolute_error: 1.5552 - val_loss: 2.3033 - val_mean_absolute_error: 2.3033
# Epoch 47/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.9677 - mean_absolute_error: 1.9677 - val_loss: 2.1764 - val_mean_absolute_error: 2.1764
# Epoch 48/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.9277 - mean_absolute_error: 1.9277 - val_loss: 1.8841 - val_mean_absolute_error: 1.8841
# Epoch 49/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.7344 - mean_absolute_error: 1.7344 - val_loss: 1.6905 - val_mean_absolute_error: 1.6905
# Epoch 50/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.7189 - mean_absolute_error: 1.7189 - val_loss: 0.9916 - val_mean_absolute_error: 0.9916
# Epoch 51/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.8961 - mean_absolute_error: 1.8961 - val_loss: 1.5093 - val_mean_absolute_error: 1.5093
# Epoch 52/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.6292 - mean_absolute_error: 1.6292 - val_loss: 1.6219 - val_mean_absolute_error: 1.6219
# Epoch 53/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.7078 - mean_absolute_error: 1.7078 - val_loss: 1.4604 - val_mean_absolute_error: 1.4604
# Epoch 54/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.7314 - mean_absolute_error: 1.7314 - val_loss: 1.7267 - val_mean_absolute_error: 1.7267
# Epoch 55/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.8050 - mean_absolute_error: 1.8050 - val_loss: 1.9363 - val_mean_absolute_error: 1.9363
# Epoch 56/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.5875 - mean_absolute_error: 1.5875 - val_loss: 1.6360 - val_mean_absolute_error: 1.6360
# Epoch 57/1000
# 46/46 [==============================] - 0s 499us/step - loss: 1.5679 - mean_absolute_error: 1.5679 - val_loss: 1.4581 - val_mean_absolute_error: 1.4581
# Epoch 58/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.6080 - mean_absolute_error: 1.6080 - val_loss: 1.5079 - val_mean_absolute_error: 1.5079
# Epoch 59/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.5717 - mean_absolute_error: 1.5717 - val_loss: 1.7098 - val_mean_absolute_error: 1.7098
# Epoch 60/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.5866 - mean_absolute_error: 1.5866 - val_loss: 1.9157 - val_mean_absolute_error: 1.9157
# Epoch 61/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.5358 - mean_absolute_error: 1.5358 - val_loss: 2.1866 - val_mean_absolute_error: 2.1866
# Epoch 62/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.6600 - mean_absolute_error: 1.6600 - val_loss: 2.2074 - val_mean_absolute_error: 2.2074
# Epoch 63/1000
# 46/46 [==============================] - ETA: 0s - loss: 1.3229 - mean_absolute_error: 1.322 - 0s 455us/step - loss: 1.6572 - mean_absolute_error: 1.6572 - val_loss: 1.9771 - val_mean_absolute_error: 1.9771
# Epoch 64/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.5270 - mean_absolute_error: 1.5270 - val_loss: 1.3427 - val_mean_absolute_error: 1.3427
# Epoch 65/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.5268 - mean_absolute_error: 1.5268 - val_loss: 0.7892 - val_mean_absolute_error: 0.7892
# Epoch 66/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.6782 - mean_absolute_error: 1.6782 - val_loss: 1.8583 - val_mean_absolute_error: 1.8583
# Epoch 67/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.5331 - mean_absolute_error: 1.5331 - val_loss: 2.3571 - val_mean_absolute_error: 2.3571
# Epoch 68/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.7720 - mean_absolute_error: 1.7720 - val_loss: 2.3862 - val_mean_absolute_error: 2.3862
# Epoch 69/1000
# 46/46 [==============================] - 0s 499us/step - loss: 1.8120 - mean_absolute_error: 1.8120 - val_loss: 2.2309 - val_mean_absolute_error: 2.2309
# Epoch 70/1000
# 46/46 [==============================] - 0s 499us/step - loss: 1.5871 - mean_absolute_error: 1.5871 - val_loss: 1.8109 - val_mean_absolute_error: 1.8109
# Epoch 71/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.5238 - mean_absolute_error: 1.5238 - val_loss: 1.0459 - val_mean_absolute_error: 1.0459
# Epoch 72/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.7712 - mean_absolute_error: 1.7712 - val_loss: 1.2955 - val_mean_absolute_error: 1.2955
# Epoch 73/1000
# 46/46 [==============================] - 0s 629us/step - loss: 1.5189 - mean_absolute_error: 1.5189 - val_loss: 2.0480 - val_mean_absolute_error: 2.0480
# Epoch 74/1000
# 46/46 [==============================] - 0s 585us/step - loss: 1.5383 - mean_absolute_error: 1.5383 - val_loss: 2.2873 - val_mean_absolute_error: 2.2873
# Epoch 75/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.5425 - mean_absolute_error: 1.5425 - val_loss: 2.1483 - val_mean_absolute_error: 2.1483
# Epoch 76/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.4752 - mean_absolute_error: 1.4752 - val_loss: 1.7999 - val_mean_absolute_error: 1.7999
# Epoch 77/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.4823 - mean_absolute_error: 1.4823 - val_loss: 1.2192 - val_mean_absolute_error: 1.2192
# Epoch 78/1000
# 46/46 [==============================] - 0s 520us/step - loss: 1.5799 - mean_absolute_error: 1.5799 - val_loss: 1.1549 - val_mean_absolute_error: 1.1549
# Epoch 79/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.5593 - mean_absolute_error: 1.5593 - val_loss: 1.7311 - val_mean_absolute_error: 1.7311
# Epoch 80/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.4805 - mean_absolute_error: 1.4805 - val_loss: 2.1965 - val_mean_absolute_error: 2.1965
# Epoch 81/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.4880 - mean_absolute_error: 1.4880 - val_loss: 2.3143 - val_mean_absolute_error: 2.3143
# Epoch 82/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.7270 - mean_absolute_error: 1.7270 - val_loss: 2.1895 - val_mean_absolute_error: 2.1895
# Epoch 83/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.5722 - mean_absolute_error: 1.5722 - val_loss: 1.6877 - val_mean_absolute_error: 1.6877
# Epoch 84/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.5184 - mean_absolute_error: 1.5184 - val_loss: 1.0447 - val_mean_absolute_error: 1.0447
# Epoch 85/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.6334 - mean_absolute_error: 1.6334 - val_loss: 1.0420 - val_mean_absolute_error: 1.0420
# Epoch 86/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.4929 - mean_absolute_error: 1.4929 - val_loss: 1.6299 - val_mean_absolute_error: 1.6299
# Epoch 87/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.4268 - mean_absolute_error: 1.4268 - val_loss: 2.0214 - val_mean_absolute_error: 2.0214
# Epoch 88/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.4568 - mean_absolute_error: 1.4568 - val_loss: 2.1214 - val_mean_absolute_error: 2.1214
# Epoch 89/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.5192 - mean_absolute_error: 1.5192 - val_loss: 2.0274 - val_mean_absolute_error: 2.0274
# Epoch 90/1000
# 46/46 [==============================] - 0s 542us/step - loss: 1.4771 - mean_absolute_error: 1.4771 - val_loss: 1.6577 - val_mean_absolute_error: 1.6577
# Epoch 91/1000
# 46/46 [==============================] - 0s 542us/step - loss: 1.3261 - mean_absolute_error: 1.3261 - val_loss: 0.8445 - val_mean_absolute_error: 0.8445
# Epoch 92/1000
# 46/46 [==============================] - 0s 499us/step - loss: 1.5054 - mean_absolute_error: 1.5054 - val_loss: 0.7890 - val_mean_absolute_error: 0.7890
# Epoch 93/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.5019 - mean_absolute_error: 1.5019 - val_loss: 1.6089 - val_mean_absolute_error: 1.6089
# Epoch 94/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.3628 - mean_absolute_error: 1.3628 - val_loss: 2.0435 - val_mean_absolute_error: 2.0435
# Epoch 95/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.4753 - mean_absolute_error: 1.4753 - val_loss: 2.1113 - val_mean_absolute_error: 2.1113
# Epoch 96/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.4698 - mean_absolute_error: 1.4698 - val_loss: 1.7668 - val_mean_absolute_error: 1.7668
# Epoch 97/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.3653 - mean_absolute_error: 1.3653 - val_loss: 1.4096 - val_mean_absolute_error: 1.4096
# Epoch 98/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.3774 - mean_absolute_error: 1.3774 - val_loss: 0.8619 - val_mean_absolute_error: 0.8619
# Epoch 99/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.5400 - mean_absolute_error: 1.5400 - val_loss: 0.9619 - val_mean_absolute_error: 0.9619
# Epoch 100/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.3939 - mean_absolute_error: 1.3939 - val_loss: 1.7886 - val_mean_absolute_error: 1.7886
# Epoch 101/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.4188 - mean_absolute_error: 1.4188 - val_loss: 2.2259 - val_mean_absolute_error: 2.2259
# Epoch 102/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.5424 - mean_absolute_error: 1.5424 - val_loss: 2.2296 - val_mean_absolute_error: 2.2296
# Epoch 103/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.5117 - mean_absolute_error: 1.5117 - val_loss: 1.7774 - val_mean_absolute_error: 1.7774
# Epoch 104/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.4009 - mean_absolute_error: 1.4009 - val_loss: 1.2801 - val_mean_absolute_error: 1.2801
# Epoch 105/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.4065 - mean_absolute_error: 1.4065 - val_loss: 0.9940 - val_mean_absolute_error: 0.9940
# Epoch 106/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.4278 - mean_absolute_error: 1.4278 - val_loss: 1.0239 - val_mean_absolute_error: 1.0239
# Epoch 107/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.3765 - mean_absolute_error: 1.3765 - val_loss: 1.0655 - val_mean_absolute_error: 1.0655
# Epoch 108/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.3533 - mean_absolute_error: 1.3533 - val_loss: 1.0278 - val_mean_absolute_error: 1.0278
# Epoch 109/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.3320 - mean_absolute_error: 1.3320 - val_loss: 0.7916 - val_mean_absolute_error: 0.7916
# Epoch 110/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.3371 - mean_absolute_error: 1.3371 - val_loss: 1.2927 - val_mean_absolute_error: 1.2927
# Epoch 111/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.3674 - mean_absolute_error: 1.3674 - val_loss: 1.5385 - val_mean_absolute_error: 1.5385
# Epoch 112/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.3090 - mean_absolute_error: 1.3090 - val_loss: 1.5102 - val_mean_absolute_error: 1.5102
# Epoch 113/1000
# 46/46 [==============================] - 0s 499us/step - loss: 1.3476 - mean_absolute_error: 1.3476 - val_loss: 1.3321 - val_mean_absolute_error: 1.3321
# Epoch 114/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.2392 - mean_absolute_error: 1.2392 - val_loss: 0.5667 - val_mean_absolute_error: 0.5667
# Epoch 115/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.4461 - mean_absolute_error: 1.4461 - val_loss: 0.8095 - val_mean_absolute_error: 0.8095
# Epoch 116/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.3970 - mean_absolute_error: 1.3970 - val_loss: 1.7516 - val_mean_absolute_error: 1.7516
# Epoch 117/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.4328 - mean_absolute_error: 1.4328 - val_loss: 1.8302 - val_mean_absolute_error: 1.8302
# Epoch 118/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.3974 - mean_absolute_error: 1.3974 - val_loss: 1.3299 - val_mean_absolute_error: 1.3299
# Epoch 119/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.2249 - mean_absolute_error: 1.2249 - val_loss: 0.5026 - val_mean_absolute_error: 0.5026
# Epoch 120/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.3501 - mean_absolute_error: 1.3501 - val_loss: 0.7387 - val_mean_absolute_error: 0.7387
# Epoch 121/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.2192 - mean_absolute_error: 1.2192 - val_loss: 1.4696 - val_mean_absolute_error: 1.4696
# Epoch 122/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.2189 - mean_absolute_error: 1.2189 - val_loss: 1.9418 - val_mean_absolute_error: 1.9418
# Epoch 123/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.4321 - mean_absolute_error: 1.4321 - val_loss: 2.1003 - val_mean_absolute_error: 2.1003
# Epoch 124/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.5627 - mean_absolute_error: 1.5627 - val_loss: 1.8810 - val_mean_absolute_error: 1.8810
# Epoch 125/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.4566 - mean_absolute_error: 1.4566 - val_loss: 1.4067 - val_mean_absolute_error: 1.4067
# Epoch 126/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.2996 - mean_absolute_error: 1.2996 - val_loss: 0.9238 - val_mean_absolute_error: 0.9238
# Epoch 127/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.3302 - mean_absolute_error: 1.3302 - val_loss: 0.6180 - val_mean_absolute_error: 0.6180
# Epoch 128/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.2951 - mean_absolute_error: 1.2951 - val_loss: 1.1206 - val_mean_absolute_error: 1.1206
# Epoch 129/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.2063 - mean_absolute_error: 1.2063 - val_loss: 1.7673 - val_mean_absolute_error: 1.7673
# Epoch 130/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.3411 - mean_absolute_error: 1.3411 - val_loss: 1.9229 - val_mean_absolute_error: 1.9229
# Epoch 131/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.4542 - mean_absolute_error: 1.4542 - val_loss: 1.7061 - val_mean_absolute_error: 1.7061
# Epoch 132/1000
# 46/46 [==============================] - 0s 347us/step - loss: 1.3313 - mean_absolute_error: 1.3313 - val_loss: 0.9292 - val_mean_absolute_error: 0.9292
# Epoch 133/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.1687 - mean_absolute_error: 1.1687 - val_loss: 0.4303 - val_mean_absolute_error: 0.4303
# Epoch 134/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.2462 - mean_absolute_error: 1.2462 - val_loss: 0.9944 - val_mean_absolute_error: 0.9944
# Epoch 135/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.2189 - mean_absolute_error: 1.2189 - val_loss: 1.5562 - val_mean_absolute_error: 1.5562
# Epoch 136/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.2501 - mean_absolute_error: 1.2501 - val_loss: 1.4438 - val_mean_absolute_error: 1.4438
# Epoch 137/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.2587 - mean_absolute_error: 1.2587 - val_loss: 0.8635 - val_mean_absolute_error: 0.8635
# Epoch 138/1000
# 46/46 [==============================] - 0s 499us/step - loss: 1.2152 - mean_absolute_error: 1.2152 - val_loss: 0.7624 - val_mean_absolute_error: 0.7624
# Epoch 139/1000
# 46/46 [==============================] - ETA: 0s - loss: 0.8391 - mean_absolute_error: 0.839 - 0s 434us/step - loss: 1.1517 - mean_absolute_error: 1.1517 - val_loss: 1.1509 - val_mean_absolute_error: 1.1509
# Epoch 140/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.2152 - mean_absolute_error: 1.2152 - val_loss: 1.5779 - val_mean_absolute_error: 1.5779
# Epoch 141/1000
# 46/46 [==============================] - 0s 520us/step - loss: 1.2261 - mean_absolute_error: 1.2261 - val_loss: 1.4504 - val_mean_absolute_error: 1.4504
# Epoch 142/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.1796 - mean_absolute_error: 1.1796 - val_loss: 1.1274 - val_mean_absolute_error: 1.1274
# Epoch 143/1000
# 46/46 [==============================] - 0s 499us/step - loss: 1.1404 - mean_absolute_error: 1.1404 - val_loss: 0.7769 - val_mean_absolute_error: 0.7769
# Epoch 144/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.1200 - mean_absolute_error: 1.1200 - val_loss: 0.4894 - val_mean_absolute_error: 0.4894
# Epoch 145/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.1590 - mean_absolute_error: 1.1590 - val_loss: 0.7264 - val_mean_absolute_error: 0.7264
# Epoch 146/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.0868 - mean_absolute_error: 1.0868 - val_loss: 1.2376 - val_mean_absolute_error: 1.2376
# Epoch 147/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.2795 - mean_absolute_error: 1.2795 - val_loss: 1.0361 - val_mean_absolute_error: 1.0361
# Epoch 148/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.0689 - mean_absolute_error: 1.0689 - val_loss: 0.6156 - val_mean_absolute_error: 0.6156
# Epoch 149/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.3376 - mean_absolute_error: 1.3376 - val_loss: 0.5544 - val_mean_absolute_error: 0.5544
# Epoch 150/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.0546 - mean_absolute_error: 1.0546 - val_loss: 1.3067 - val_mean_absolute_error: 1.3067
# Epoch 151/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.1841 - mean_absolute_error: 1.1841 - val_loss: 1.2547 - val_mean_absolute_error: 1.2547
# Epoch 152/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.1218 - mean_absolute_error: 1.1218 - val_loss: 0.8414 - val_mean_absolute_error: 0.8414
# Epoch 153/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.1599 - mean_absolute_error: 1.1599 - val_loss: 0.4080 - val_mean_absolute_error: 0.4080
# Epoch 154/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.0820 - mean_absolute_error: 1.0820 - val_loss: 1.1607 - val_mean_absolute_error: 1.1607
# Epoch 155/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.2176 - mean_absolute_error: 1.2176 - val_loss: 1.7338 - val_mean_absolute_error: 1.7338
# Epoch 156/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.2803 - mean_absolute_error: 1.2803 - val_loss: 1.5082 - val_mean_absolute_error: 1.5082
# Epoch 157/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.1235 - mean_absolute_error: 1.1235 - val_loss: 0.9362 - val_mean_absolute_error: 0.9362
# Epoch 158/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.0922 - mean_absolute_error: 1.0922 - val_loss: 0.4333 - val_mean_absolute_error: 0.4333
# Epoch 159/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.1619 - mean_absolute_error: 1.1619 - val_loss: 0.5413 - val_mean_absolute_error: 0.5413
# Epoch 160/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.0480 - mean_absolute_error: 1.0480 - val_loss: 0.7250 - val_mean_absolute_error: 0.7250
# Epoch 161/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.0620 - mean_absolute_error: 1.0620 - val_loss: 0.4822 - val_mean_absolute_error: 0.4822
# Epoch 162/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.0517 - mean_absolute_error: 1.0517 - val_loss: 0.3695 - val_mean_absolute_error: 0.3695
# Epoch 163/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.1027 - mean_absolute_error: 1.1027 - val_loss: 0.5004 - val_mean_absolute_error: 0.5004
# Epoch 164/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.0132 - mean_absolute_error: 1.0132 - val_loss: 0.4987 - val_mean_absolute_error: 0.4987
# Epoch 165/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.9981 - mean_absolute_error: 0.9981 - val_loss: 0.4398 - val_mean_absolute_error: 0.4398
# Epoch 166/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.0078 - mean_absolute_error: 1.0078 - val_loss: 0.6501 - val_mean_absolute_error: 0.6501
# Epoch 167/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.0257 - mean_absolute_error: 1.0257 - val_loss: 1.0877 - val_mean_absolute_error: 1.0877
# Epoch 168/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.0961 - mean_absolute_error: 1.0961 - val_loss: 0.7768 - val_mean_absolute_error: 0.7768
# Epoch 169/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.0072 - mean_absolute_error: 1.0072 - val_loss: 0.4553 - val_mean_absolute_error: 0.4553
# Epoch 170/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.9751 - mean_absolute_error: 0.9751 - val_loss: 0.4070 - val_mean_absolute_error: 0.4070
# Epoch 171/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.9829 - mean_absolute_error: 0.9829 - val_loss: 0.4259 - val_mean_absolute_error: 0.4259
# Epoch 172/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.9275 - mean_absolute_error: 0.9275 - val_loss: 0.7390 - val_mean_absolute_error: 0.7390
# Epoch 173/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.0552 - mean_absolute_error: 1.0552 - val_loss: 0.5700 - val_mean_absolute_error: 0.5700
# Epoch 174/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.9871 - mean_absolute_error: 0.9871 - val_loss: 1.0152 - val_mean_absolute_error: 1.0152
# Epoch 175/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.0220 - mean_absolute_error: 1.0220 - val_loss: 0.4149 - val_mean_absolute_error: 0.4149
# Epoch 176/1000
# 46/46 [==============================] - 0s 477us/step - loss: 1.0268 - mean_absolute_error: 1.0268 - val_loss: 0.6865 - val_mean_absolute_error: 0.6865
# Epoch 177/1000
# 46/46 [==============================] - 0s 434us/step - loss: 1.0454 - mean_absolute_error: 1.0454 - val_loss: 1.1142 - val_mean_absolute_error: 1.1142
# Epoch 178/1000
# 46/46 [==============================] - 0s 412us/step - loss: 1.0078 - mean_absolute_error: 1.0078 - val_loss: 1.6296 - val_mean_absolute_error: 1.6296
# Epoch 179/1000
# 46/46 [==============================] - 0s 455us/step - loss: 1.2846 - mean_absolute_error: 1.2846 - val_loss: 1.2880 - val_mean_absolute_error: 1.2880
# Epoch 180/1000
# 46/46 [==============================] - 0s 390us/step - loss: 1.1235 - mean_absolute_error: 1.1235 - val_loss: 0.4746 - val_mean_absolute_error: 0.4746
# Epoch 181/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.9651 - mean_absolute_error: 0.9651 - val_loss: 0.6679 - val_mean_absolute_error: 0.6679
# Epoch 182/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.1760 - mean_absolute_error: 1.1760 - val_loss: 0.3653 - val_mean_absolute_error: 0.3653
# Epoch 183/1000
# 46/46 [==============================] - 0s 369us/step - loss: 0.9265 - mean_absolute_error: 0.9265 - val_loss: 0.6571 - val_mean_absolute_error: 0.6571
# Epoch 184/1000
# 46/46 [==============================] - 0s 390us/step - loss: 0.9819 - mean_absolute_error: 0.9819 - val_loss: 0.6503 - val_mean_absolute_error: 0.6503
# Epoch 185/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.9569 - mean_absolute_error: 0.9569 - val_loss: 0.3990 - val_mean_absolute_error: 0.3990
# Epoch 186/1000
# 46/46 [==============================] - 0s 369us/step - loss: 1.0337 - mean_absolute_error: 1.0337 - val_loss: 0.4416 - val_mean_absolute_error: 0.4416
# Epoch 187/1000
# 46/46 [==============================] - 0s 520us/step - loss: 0.9376 - mean_absolute_error: 0.9376 - val_loss: 0.3989 - val_mean_absolute_error: 0.3989
# Epoch 188/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.9229 - mean_absolute_error: 0.9229 - val_loss: 0.4071 - val_mean_absolute_error: 0.4071
# Epoch 189/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.9749 - mean_absolute_error: 0.9749 - val_loss: 1.0047 - val_mean_absolute_error: 1.0047
# Epoch 190/1000
# 46/46 [==============================] - 0s 369us/step - loss: 0.9534 - mean_absolute_error: 0.9534 - val_loss: 0.6677 - val_mean_absolute_error: 0.6677
# Epoch 191/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.8981 - mean_absolute_error: 0.8981 - val_loss: 0.7757 - val_mean_absolute_error: 0.7757
# Epoch 192/1000
# 46/46 [==============================] - 0s 369us/step - loss: 0.9171 - mean_absolute_error: 0.9171 - val_loss: 0.5115 - val_mean_absolute_error: 0.5115
# Epoch 193/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.8933 - mean_absolute_error: 0.8933 - val_loss: 0.4446 - val_mean_absolute_error: 0.4446
# Epoch 194/1000
# 46/46 [==============================] - 0s 390us/step - loss: 0.8743 - mean_absolute_error: 0.8743 - val_loss: 0.6285 - val_mean_absolute_error: 0.6285
# Epoch 195/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.8639 - mean_absolute_error: 0.8639 - val_loss: 0.3836 - val_mean_absolute_error: 0.3836
# Epoch 196/1000
# 46/46 [==============================] - 0s 390us/step - loss: 0.8582 - mean_absolute_error: 0.8582 - val_loss: 0.4797 - val_mean_absolute_error: 0.4797
# Epoch 197/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.8569 - mean_absolute_error: 0.8569 - val_loss: 0.7938 - val_mean_absolute_error: 0.7938
# Epoch 198/1000
# 46/46 [==============================] - 0s 390us/step - loss: 0.8487 - mean_absolute_error: 0.8487 - val_loss: 0.8695 - val_mean_absolute_error: 0.8695
# Epoch 199/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.8409 - mean_absolute_error: 0.8409 - val_loss: 0.5822 - val_mean_absolute_error: 0.5822
# Epoch 200/1000
# 46/46 [==============================] - 0s 889us/step - loss: 0.7700 - mean_absolute_error: 0.7700 - val_loss: 0.5575 - val_mean_absolute_error: 0.5575
# Epoch 201/1000
# 46/46 [==============================] - 0s 889us/step - loss: 0.7629 - mean_absolute_error: 0.7629 - val_loss: 0.4938 - val_mean_absolute_error: 0.4938
# Epoch 202/1000
# 46/46 [==============================] - 0s 715us/step - loss: 0.8385 - mean_absolute_error: 0.8385 - val_loss: 0.4982 - val_mean_absolute_error: 0.4982
# Epoch 203/1000
# 46/46 [==============================] - 0s 650us/step - loss: 0.7603 - mean_absolute_error: 0.7603 - val_loss: 0.3848 - val_mean_absolute_error: 0.3848
# Epoch 204/1000
# 46/46 [==============================] - 0s 932us/step - loss: 0.7954 - mean_absolute_error: 0.7954 - val_loss: 0.6338 - val_mean_absolute_error: 0.6338
# Epoch 205/1000
# 46/46 [==============================] - 0s 824us/step - loss: 0.7401 - mean_absolute_error: 0.7401 - val_loss: 0.8983 - val_mean_absolute_error: 0.8983
# Epoch 206/1000
# 46/46 [==============================] - 0s 846us/step - loss: 0.7291 - mean_absolute_error: 0.7291 - val_loss: 0.5548 - val_mean_absolute_error: 0.5548
# Epoch 207/1000
# 46/46 [==============================] - 0s 759us/step - loss: 0.8057 - mean_absolute_error: 0.8057 - val_loss: 1.0036 - val_mean_absolute_error: 1.0036
# Epoch 208/1000
# 46/46 [==============================] - 0s 737us/step - loss: 0.8035 - mean_absolute_error: 0.8035 - val_loss: 0.7339 - val_mean_absolute_error: 0.7339
# Epoch 209/1000
# 46/46 [==============================] - 0s 715us/step - loss: 0.7131 - mean_absolute_error: 0.7131 - val_loss: 0.5072 - val_mean_absolute_error: 0.5072
# Epoch 210/1000
# 46/46 [==============================] - 0s 672us/step - loss: 0.8029 - mean_absolute_error: 0.8029 - val_loss: 1.1802 - val_mean_absolute_error: 1.1802
# Epoch 211/1000
# 46/46 [==============================] - 0s 911us/step - loss: 0.7581 - mean_absolute_error: 0.7581 - val_loss: 1.0270 - val_mean_absolute_error: 1.0270
# Epoch 212/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.7086 - mean_absolute_error: 0.7086 - val_loss: 0.4078 - val_mean_absolute_error: 0.4078
# Epoch 213/1000
# 46/46 [==============================] - 0s 694us/step - loss: 0.8033 - mean_absolute_error: 0.8033 - val_loss: 0.3804 - val_mean_absolute_error: 0.3804
# Epoch 214/1000
# 46/46 [==============================] - 0s 780us/step - loss: 0.8444 - mean_absolute_error: 0.8444 - val_loss: 0.5461 - val_mean_absolute_error: 0.5461
# Epoch 215/1000
# 46/46 [==============================] - 0s 694us/step - loss: 0.6465 - mean_absolute_error: 0.6465 - val_loss: 1.3650 - val_mean_absolute_error: 1.3650
# Epoch 216/1000
# 46/46 [==============================] - 0s 911us/step - loss: 0.9270 - mean_absolute_error: 0.9270 - val_loss: 0.5366 - val_mean_absolute_error: 0.5366
# Epoch 217/1000
# 46/46 [==============================] - 0s 845us/step - loss: 0.7325 - mean_absolute_error: 0.7325 - val_loss: 0.6493 - val_mean_absolute_error: 0.6493
# Epoch 218/1000
# 46/46 [==============================] - 0s 780us/step - loss: 0.6932 - mean_absolute_error: 0.6932 - val_loss: 1.0930 - val_mean_absolute_error: 1.0930
# Epoch 219/1000
# 46/46 [==============================] - 0s 694us/step - loss: 0.7038 - mean_absolute_error: 0.7038 - val_loss: 0.6722 - val_mean_absolute_error: 0.6722
# Epoch 220/1000
# 46/46 [==============================] - 0s 824us/step - loss: 0.7248 - mean_absolute_error: 0.7248 - val_loss: 0.4188 - val_mean_absolute_error: 0.4188
# Epoch 221/1000
# 46/46 [==============================] - 0s 845us/step - loss: 0.9119 - mean_absolute_error: 0.9119 - val_loss: 0.8008 - val_mean_absolute_error: 0.8008
# Epoch 222/1000
# 46/46 [==============================] - 0s 737us/step - loss: 0.7928 - mean_absolute_error: 0.7928 - val_loss: 2.5445 - val_mean_absolute_error: 2.5445
# Epoch 223/1000
# 46/46 [==============================] - 0s 932us/step - loss: 1.0444 - mean_absolute_error: 1.0444 - val_loss: 0.4967 - val_mean_absolute_error: 0.4967
# Epoch 224/1000
# 46/46 [==============================] - 0s 737us/step - loss: 0.9855 - mean_absolute_error: 0.9855 - val_loss: 0.5494 - val_mean_absolute_error: 0.5494
# Epoch 225/1000
# 46/46 [==============================] - 0s 823us/step - loss: 0.6330 - mean_absolute_error: 0.6330 - val_loss: 3.1989 - val_mean_absolute_error: 3.1989
# Epoch 226/1000
# 46/46 [==============================] - 0s 759us/step - loss: 1.4907 - mean_absolute_error: 1.4907 - val_loss: 1.6170 - val_mean_absolute_error: 1.6170
# Epoch 227/1000
# 46/46 [==============================] - 0s 564us/step - loss: 0.8308 - mean_absolute_error: 0.8308 - val_loss: 1.3575 - val_mean_absolute_error: 1.3575
# Epoch 228/1000
# 46/46 [==============================] - 0s 997us/step - loss: 1.7761 - mean_absolute_error: 1.7761 - val_loss: 1.4185 - val_mean_absolute_error: 1.4185
# Epoch 229/1000
# 46/46 [==============================] - 0s 585us/step - loss: 1.5477 - mean_absolute_error: 1.5477 - val_loss: 0.9345 - val_mean_absolute_error: 0.9345
# Epoch 230/1000
# 46/46 [==============================] - 0s 607us/step - loss: 0.9420 - mean_absolute_error: 0.9420 - val_loss: 3.1287 - val_mean_absolute_error: 3.1287
# Epoch 231/1000
# 46/46 [==============================] - 0s 715us/step - loss: 1.3825 - mean_absolute_error: 1.3825 - val_loss: 0.5280 - val_mean_absolute_error: 0.5280
# Epoch 232/1000
# 46/46 [==============================] - 0s 715us/step - loss: 0.9590 - mean_absolute_error: 0.9590 - val_loss: 1.5953 - val_mean_absolute_error: 1.5953
# Epoch 233/1000
# 46/46 [==============================] - 0s 694us/step - loss: 1.9257 - mean_absolute_error: 1.9257 - val_loss: 1.4723 - val_mean_absolute_error: 1.4723
# Epoch 234/1000
# 46/46 [==============================] - 0s 672us/step - loss: 1.5400 - mean_absolute_error: 1.5400 - val_loss: 0.7600 - val_mean_absolute_error: 0.7600
# Epoch 235/1000
# 46/46 [==============================] - 0s 759us/step - loss: 0.8777 - mean_absolute_error: 0.8777 - val_loss: 3.1996 - val_mean_absolute_error: 3.1996
# Epoch 236/1000
# 46/46 [==============================] - 0s 672us/step - loss: 1.6161 - mean_absolute_error: 1.6161 - val_loss: 0.4631 - val_mean_absolute_error: 0.4631
# Epoch 237/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.7953 - mean_absolute_error: 0.7953 - val_loss: 1.2567 - val_mean_absolute_error: 1.2567
# Epoch 238/1000
# 46/46 [==============================] - 0s 651us/step - loss: 1.4315 - mean_absolute_error: 1.4315 - val_loss: 0.6564 - val_mean_absolute_error: 0.6564
# Epoch 239/1000
# 46/46 [==============================] - 0s 607us/step - loss: 0.8671 - mean_absolute_error: 0.8671 - val_loss: 1.8373 - val_mean_absolute_error: 1.8373
# Epoch 240/1000
# 46/46 [==============================] - 0s 629us/step - loss: 1.0862 - mean_absolute_error: 1.0862 - val_loss: 1.1526 - val_mean_absolute_error: 1.1526
# Epoch 241/1000
# 46/46 [==============================] - 0s 542us/step - loss: 0.5941 - mean_absolute_error: 0.5941 - val_loss: 1.0800 - val_mean_absolute_error: 1.0800
# Epoch 242/1000
# 46/46 [==============================] - 0s 824us/step - loss: 1.3151 - mean_absolute_error: 1.3151 - val_loss: 1.2405 - val_mean_absolute_error: 1.2405
# Epoch 243/1000
# 46/46 [==============================] - 0s 781us/step - loss: 1.3446 - mean_absolute_error: 1.3446 - val_loss: 0.4794 - val_mean_absolute_error: 0.4794
# Epoch 244/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.7656 - mean_absolute_error: 0.7656 - val_loss: 1.9047 - val_mean_absolute_error: 1.9047
# Epoch 245/1000
# 46/46 [==============================] - 0s 846us/step - loss: 1.0151 - mean_absolute_error: 1.0151 - val_loss: 0.7246 - val_mean_absolute_error: 0.7246
# Epoch 246/1000
# 46/46 [==============================] - 0s 997us/step - loss: 0.7102 - mean_absolute_error: 0.7102 - val_loss: 1.0274 - val_mean_absolute_error: 1.0274
# Epoch 247/1000
# 46/46 [==============================] - 0s 867us/step - loss: 1.4461 - mean_absolute_error: 1.4461 - val_loss: 0.7982 - val_mean_absolute_error: 0.7982
# Epoch 248/1000
# 46/46 [==============================] - 0s 846us/step - loss: 0.9870 - mean_absolute_error: 0.9870 - val_loss: 1.7757 - val_mean_absolute_error: 1.7757
# Epoch 249/1000
# 46/46 [==============================] - 0s 802us/step - loss: 1.0620 - mean_absolute_error: 1.0620 - val_loss: 1.6510 - val_mean_absolute_error: 1.6510
# Epoch 250/1000
# 46/46 [==============================] - 0s 520us/step - loss: 0.7141 - mean_absolute_error: 0.7141 - val_loss: 0.8123 - val_mean_absolute_error: 0.8123
# Epoch 251/1000
# 46/46 [==============================] - 0s 585us/step - loss: 1.3016 - mean_absolute_error: 1.3016 - val_loss: 1.2560 - val_mean_absolute_error: 1.2560
# Epoch 252/1000
# 46/46 [==============================] - 0s 737us/step - loss: 1.4645 - mean_absolute_error: 1.4645 - val_loss: 0.4901 - val_mean_absolute_error: 0.4901
# Epoch 253/1000
# 46/46 [==============================] - 0s 780us/step - loss: 0.9277 - mean_absolute_error: 0.9277 - val_loss: 2.4489 - val_mean_absolute_error: 2.4489
# Epoch 254/1000
# 46/46 [==============================] - 0s 780us/step - loss: 1.2991 - mean_absolute_error: 1.2991 - val_loss: 1.0077 - val_mean_absolute_error: 1.0077
# Epoch 255/1000
# 46/46 [==============================] - 0s 1ms/step - loss: 0.7734 - mean_absolute_error: 0.7734 - val_loss: 0.5414 - val_mean_absolute_error: 0.5414
# Epoch 256/1000
# 46/46 [==============================] - 0s 802us/step - loss: 0.9044 - mean_absolute_error: 0.9044 - val_loss: 0.5098 - val_mean_absolute_error: 0.5098
# Epoch 257/1000
# 46/46 [==============================] - 0s 716us/step - loss: 0.7118 - mean_absolute_error: 0.7118 - val_loss: 1.2628 - val_mean_absolute_error: 1.2628
# Epoch 258/1000
# 46/46 [==============================] - 0s 1ms/step - loss: 0.8132 - mean_absolute_error: 0.8132 - val_loss: 1.0956 - val_mean_absolute_error: 1.0956
# Epoch 259/1000
# 46/46 [==============================] - 0s 867us/step - loss: 0.6301 - mean_absolute_error: 0.6301 - val_loss: 0.4812 - val_mean_absolute_error: 0.4812
# Epoch 260/1000
# 46/46 [==============================] - 0s 694us/step - loss: 0.8618 - mean_absolute_error: 0.8618 - val_loss: 0.5304 - val_mean_absolute_error: 0.5304
# Epoch 261/1000
# 46/46 [==============================] - 0s 607us/step - loss: 0.8534 - mean_absolute_error: 0.8534 - val_loss: 1.1332 - val_mean_absolute_error: 1.1332
# Epoch 262/1000
# 46/46 [==============================] - 0s 759us/step - loss: 0.7973 - mean_absolute_error: 0.7973 - val_loss: 1.2916 - val_mean_absolute_error: 1.2916
# Epoch 263/1000
# 46/46 [==============================] - 0s 759us/step - loss: 0.6436 - mean_absolute_error: 0.6436 - val_loss: 0.4904 - val_mean_absolute_error: 0.4904
# Epoch 264/1000
# 46/46 [==============================] - 0s 802us/step - loss: 0.8834 - mean_absolute_error: 0.8834 - val_loss: 0.5553 - val_mean_absolute_error: 0.5553
# Epoch 265/1000
# 46/46 [==============================] - 0s 737us/step - loss: 0.9107 - mean_absolute_error: 0.9107 - val_loss: 1.0454 - val_mean_absolute_error: 1.0454
# Epoch 266/1000
# 46/46 [==============================] - 0s 737us/step - loss: 0.7704 - mean_absolute_error: 0.7704 - val_loss: 1.6712 - val_mean_absolute_error: 1.6712
# Epoch 267/1000
# 46/46 [==============================] - 0s 1ms/step - loss: 0.7449 - mean_absolute_error: 0.7449 - val_loss: 0.4971 - val_mean_absolute_error: 0.4971
# Epoch 268/1000
# 46/46 [==============================] - 0s 715us/step - loss: 0.7845 - mean_absolute_error: 0.7845 - val_loss: 0.6037 - val_mean_absolute_error: 0.6037
# Epoch 269/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.9595 - mean_absolute_error: 0.9595 - val_loss: 0.8308 - val_mean_absolute_error: 0.8308
# Epoch 270/1000
# 46/46 [==============================] - 0s 585us/step - loss: 0.7781 - mean_absolute_error: 0.7781 - val_loss: 1.2639 - val_mean_absolute_error: 1.2639
# Epoch 271/1000
# 46/46 [==============================] - 0s 585us/step - loss: 0.6737 - mean_absolute_error: 0.6737 - val_loss: 0.9018 - val_mean_absolute_error: 0.9018
# Epoch 272/1000
# 46/46 [==============================] - 0s 672us/step - loss: 0.6417 - mean_absolute_error: 0.6417 - val_loss: 1.1298 - val_mean_absolute_error: 1.1298
# Epoch 273/1000
# 46/46 [==============================] - 0s 2ms/step - loss: 0.6415 - mean_absolute_error: 0.6415 - val_loss: 1.4201 - val_mean_absolute_error: 1.4201
# Epoch 274/1000
# 46/46 [==============================] - 0s 1ms/step - loss: 0.7452 - mean_absolute_error: 0.7452 - val_loss: 1.0270 - val_mean_absolute_error: 1.0270
# Epoch 275/1000
# 46/46 [==============================] - 0s 781us/step - loss: 0.6304 - mean_absolute_error: 0.6304 - val_loss: 0.4714 - val_mean_absolute_error: 0.4714
# Epoch 276/1000
# 46/46 [==============================] - 0s 672us/step - loss: 0.8257 - mean_absolute_error: 0.8257 - val_loss: 0.8763 - val_mean_absolute_error: 0.8763
# Epoch 277/1000
# 46/46 [==============================] - 0s 1ms/step - loss: 0.6203 - mean_absolute_error: 0.6203 - val_loss: 1.9049 - val_mean_absolute_error: 1.9049
# Epoch 278/1000
# 46/46 [==============================] - 0s 933us/step - loss: 0.8739 - mean_absolute_error: 0.8739 - val_loss: 0.9723 - val_mean_absolute_error: 0.9723
# Epoch 279/1000
# 46/46 [==============================] - 0s 911us/step - loss: 0.6723 - mean_absolute_error: 0.6723 - val_loss: 0.4867 - val_mean_absolute_error: 0.4867
# Epoch 280/1000
# 46/46 [==============================] - 0s 975us/step - loss: 0.9545 - mean_absolute_error: 0.9545 - val_loss: 0.7416 - val_mean_absolute_error: 0.7416
# Epoch 281/1000
# 46/46 [==============================] - 0s 542us/step - loss: 0.7222 - mean_absolute_error: 0.7222 - val_loss: 1.4533 - val_mean_absolute_error: 1.4533
# Epoch 282/1000
# 46/46 [==============================] - ETA: 0s - loss: 0.4841 - mean_absolute_error: 0.484 - 0s 629us/step - loss: 0.6600 - mean_absolute_error: 0.6600 - val_loss: 1.3464 - val_mean_absolute_error: 1.3464
# Epoch 283/1000
# 46/46 [==============================] - 0s 759us/step - loss: 0.6164 - mean_absolute_error: 0.6164 - val_loss: 0.9929 - val_mean_absolute_error: 0.9929
# Epoch 284/1000
# ...
# Epoch 906/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.1850 - mean_absolute_error: 0.1850 - val_loss: 2.2050 - val_mean_absolute_error: 2.2050
# Epoch 907/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.2155 - mean_absolute_error: 0.2155 - val_loss: 1.9623 - val_mean_absolute_error: 1.9623
# Epoch 908/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.2023 - mean_absolute_error: 0.2023 - val_loss: 2.1504 - val_mean_absolute_error: 2.1504
# Epoch 909/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.1733 - mean_absolute_error: 0.1733 - val_loss: 2.1291 - val_mean_absolute_error: 2.1291
# Epoch 910/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.1728 - mean_absolute_error: 0.1728 - val_loss: 2.0177 - val_mean_absolute_error: 2.0177
# Epoch 911/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.2318 - mean_absolute_error: 0.2318 - val_loss: 2.4183 - val_mean_absolute_error: 2.4183
# Epoch 912/1000
# 46/46 [==============================] - 0s 390us/step - loss: 0.1442 - mean_absolute_error: 0.1442 - val_loss: 2.0537 - val_mean_absolute_error: 2.0537
# Epoch 913/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.2009 - mean_absolute_error: 0.2009 - val_loss: 2.3897 - val_mean_absolute_error: 2.3897
# Epoch 914/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.1528 - mean_absolute_error: 0.1528 - val_loss: 2.5665 - val_mean_absolute_error: 2.5665
# Epoch 915/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.1731 - mean_absolute_error: 0.1731 - val_loss: 2.2196 - val_mean_absolute_error: 2.2196
# Epoch 916/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.1548 - mean_absolute_error: 0.1548 - val_loss: 2.2417 - val_mean_absolute_error: 2.2417
# Epoch 917/1000
# 46/46 [==============================] - 0s 390us/step - loss: 0.1344 - mean_absolute_error: 0.1344 - val_loss: 2.0110 - val_mean_absolute_error: 2.0110
# Epoch 918/1000
# 46/46 [==============================] - 0s 477us/step - loss: 0.1814 - mean_absolute_error: 0.1814 - val_loss: 2.5570 - val_mean_absolute_error: 2.5570
# Epoch 919/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.1790 - mean_absolute_error: 0.1790 - val_loss: 2.3508 - val_mean_absolute_error: 2.3508
# Epoch 920/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.1631 - mean_absolute_error: 0.1631 - val_loss: 1.9665 - val_mean_absolute_error: 1.9665
# Epoch 921/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.1893 - mean_absolute_error: 0.1893 - val_loss: 2.4089 - val_mean_absolute_error: 2.4089
# Epoch 922/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.1617 - mean_absolute_error: 0.1617 - val_loss: 2.1189 - val_mean_absolute_error: 2.1189
# Epoch 923/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.1620 - mean_absolute_error: 0.1620 - val_loss: 2.2409 - val_mean_absolute_error: 2.2409
# Epoch 924/1000
# 46/46 [==============================] - 0s 477us/step - loss: 0.1544 - mean_absolute_error: 0.1544 - val_loss: 2.6066 - val_mean_absolute_error: 2.6066
# Epoch 925/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.2174 - mean_absolute_error: 0.2174 - val_loss: 2.2172 - val_mean_absolute_error: 2.2172
# Epoch 926/1000
# 46/46 [==============================] - 0s 585us/step - loss: 0.1493 - mean_absolute_error: 0.1493 - val_loss: 2.7728 - val_mean_absolute_error: 2.7728
# Epoch 927/1000
# 46/46 [==============================] - 0s 542us/step - loss: 0.3283 - mean_absolute_error: 0.3283 - val_loss: 1.9057 - val_mean_absolute_error: 1.9057
# Epoch 928/1000
# 46/46 [==============================] - 0s 564us/step - loss: 0.2978 - mean_absolute_error: 0.2978 - val_loss: 1.9322 - val_mean_absolute_error: 1.9322
# Epoch 929/1000
# 46/46 [==============================] - 0s 737us/step - loss: 0.2447 - mean_absolute_error: 0.2447 - val_loss: 2.9117 - val_mean_absolute_error: 2.9117
# Epoch 930/1000
# 46/46 [==============================] - 0s 759us/step - loss: 0.3025 - mean_absolute_error: 0.3025 - val_loss: 1.9633 - val_mean_absolute_error: 1.9633
# Epoch 931/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.2153 - mean_absolute_error: 0.2153 - val_loss: 2.4107 - val_mean_absolute_error: 2.4107
# Epoch 932/1000
# 46/46 [==============================] - 0s 650us/step - loss: 0.2480 - mean_absolute_error: 0.2480 - val_loss: 2.1931 - val_mean_absolute_error: 2.1931
# Epoch 933/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.1806 - mean_absolute_error: 0.1806 - val_loss: 1.6847 - val_mean_absolute_error: 1.6847
# Epoch 934/1000
# 46/46 [==============================] - 0s 477us/step - loss: 0.3753 - mean_absolute_error: 0.3753 - val_loss: 2.5577 - val_mean_absolute_error: 2.5577
# Epoch 935/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.2128 - mean_absolute_error: 0.2128 - val_loss: 2.8472 - val_mean_absolute_error: 2.8472
# Epoch 936/1000
# 46/46 [==============================] - 0s 477us/step - loss: 0.3823 - mean_absolute_error: 0.3823 - val_loss: 1.5716 - val_mean_absolute_error: 1.5716
# Epoch 937/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.3228 - mean_absolute_error: 0.3228 - val_loss: 2.2442 - val_mean_absolute_error: 2.2442
# Epoch 938/1000
# 46/46 [==============================] - 0s 585us/step - loss: 0.2491 - mean_absolute_error: 0.2491 - val_loss: 2.5434 - val_mean_absolute_error: 2.5434
# Epoch 939/1000
# 46/46 [==============================] - 0s 586us/step - loss: 0.2799 - mean_absolute_error: 0.2799 - val_loss: 1.9353 - val_mean_absolute_error: 1.9353
# Epoch 940/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.2538 - mean_absolute_error: 0.2538 - val_loss: 2.5236 - val_mean_absolute_error: 2.5236
# Epoch 941/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.1976 - mean_absolute_error: 0.1976 - val_loss: 2.8680 - val_mean_absolute_error: 2.8680
# Epoch 942/1000
# 46/46 [==============================] - 0s 563us/step - loss: 0.2545 - mean_absolute_error: 0.2545 - val_loss: 2.0197 - val_mean_absolute_error: 2.0197
# Epoch 943/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.2006 - mean_absolute_error: 0.2006 - val_loss: 1.9981 - val_mean_absolute_error: 1.9981
# Epoch 944/1000
# 46/46 [==============================] - 0s 520us/step - loss: 0.1506 - mean_absolute_error: 0.1506 - val_loss: 2.3094 - val_mean_absolute_error: 2.3094
# Epoch 945/1000
# 46/46 [==============================] - 0s 694us/step - loss: 0.2230 - mean_absolute_error: 0.2230 - val_loss: 2.0282 - val_mean_absolute_error: 2.0282
# Epoch 946/1000
# 46/46 [==============================] - 0s 672us/step - loss: 0.2073 - mean_absolute_error: 0.2073 - val_loss: 2.2805 - val_mean_absolute_error: 2.2805
# Epoch 947/1000
# 46/46 [==============================] - 0s 542us/step - loss: 0.2274 - mean_absolute_error: 0.2274 - val_loss: 2.5170 - val_mean_absolute_error: 2.5170
# Epoch 948/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.1873 - mean_absolute_error: 0.1873 - val_loss: 2.1859 - val_mean_absolute_error: 2.1859
# Epoch 949/1000
# 46/46 [==============================] - 0s 650us/step - loss: 0.1722 - mean_absolute_error: 0.1722 - val_loss: 2.2490 - val_mean_absolute_error: 2.2490
# Epoch 950/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.1268 - mean_absolute_error: 0.1268 - val_loss: 2.2205 - val_mean_absolute_error: 2.2205
# Epoch 951/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.1935 - mean_absolute_error: 0.1935 - val_loss: 1.8575 - val_mean_absolute_error: 1.8575
# Epoch 952/1000
# 46/46 [==============================] - 0s 672us/step - loss: 0.1601 - mean_absolute_error: 0.1601 - val_loss: 2.2918 - val_mean_absolute_error: 2.2918
# Epoch 953/1000
# 46/46 [==============================] - 0s 585us/step - loss: 0.2459 - mean_absolute_error: 0.2459 - val_loss: 1.5343 - val_mean_absolute_error: 1.5343
# Epoch 954/1000
# 46/46 [==============================] - 0s 650us/step - loss: 0.4268 - mean_absolute_error: 0.4268 - val_loss: 1.8044 - val_mean_absolute_error: 1.8044
# Epoch 955/1000
# 46/46 [==============================] - 0s 542us/step - loss: 0.3836 - mean_absolute_error: 0.3836 - val_loss: 3.5272 - val_mean_absolute_error: 3.5272
# Epoch 956/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.5960 - mean_absolute_error: 0.5960 - val_loss: 2.7717 - val_mean_absolute_error: 2.7717
# Epoch 957/1000
# 46/46 [==============================] - 0s 607us/step - loss: 0.3496 - mean_absolute_error: 0.3496 - val_loss: 1.7585 - val_mean_absolute_error: 1.7585
# Epoch 958/1000
# 46/46 [==============================] - 0s 521us/step - loss: 0.5442 - mean_absolute_error: 0.5442 - val_loss: 3.1459 - val_mean_absolute_error: 3.1459
# Epoch 959/1000
# 46/46 [==============================] - 0s 564us/step - loss: 0.3935 - mean_absolute_error: 0.3935 - val_loss: 3.7522 - val_mean_absolute_error: 3.7522
# Epoch 960/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.5593 - mean_absolute_error: 0.5593 - val_loss: 2.8591 - val_mean_absolute_error: 2.8591
# Epoch 961/1000
# 46/46 [==============================] - 0s 694us/step - loss: 0.2923 - mean_absolute_error: 0.2923 - val_loss: 1.5474 - val_mean_absolute_error: 1.5474
# Epoch 962/1000
# 46/46 [==============================] - 0s 716us/step - loss: 0.2997 - mean_absolute_error: 0.2997 - val_loss: 2.1354 - val_mean_absolute_error: 2.1354
# Epoch 963/1000
# 46/46 [==============================] - 0s 520us/step - loss: 0.7288 - mean_absolute_error: 0.7288 - val_loss: 1.5659 - val_mean_absolute_error: 1.5659
# Epoch 964/1000
# 46/46 [==============================] - 0s 564us/step - loss: 0.4193 - mean_absolute_error: 0.4193 - val_loss: 0.9955 - val_mean_absolute_error: 0.9955
# Epoch 965/1000
# 46/46 [==============================] - 0s 564us/step - loss: 0.7944 - mean_absolute_error: 0.7944 - val_loss: 1.4162 - val_mean_absolute_error: 1.4162
# Epoch 966/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.5388 - mean_absolute_error: 0.5388 - val_loss: 3.0191 - val_mean_absolute_error: 3.0191
# Epoch 967/1000
# 46/46 [==============================] - 0s 520us/step - loss: 0.5191 - mean_absolute_error: 0.5191 - val_loss: 3.4650 - val_mean_absolute_error: 3.4650
# Epoch 968/1000
# 46/46 [==============================] - 0s 434us/step - loss: 0.5187 - mean_absolute_error: 0.5187 - val_loss: 2.0063 - val_mean_absolute_error: 2.0063
# Epoch 969/1000
# 46/46 [==============================] - 0s 390us/step - loss: 0.3176 - mean_absolute_error: 0.3176 - val_loss: 1.3515 - val_mean_absolute_error: 1.3515
# Epoch 970/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.4707 - mean_absolute_error: 0.4707 - val_loss: 2.4419 - val_mean_absolute_error: 2.4419
# Epoch 971/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.4556 - mean_absolute_error: 0.4556 - val_loss: 2.3644 - val_mean_absolute_error: 2.3644
# Epoch 972/1000
# 46/46 [==============================] - 0s 477us/step - loss: 0.4033 - mean_absolute_error: 0.4033 - val_loss: 1.3141 - val_mean_absolute_error: 1.3141
# Epoch 973/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.5062 - mean_absolute_error: 0.5062 - val_loss: 1.9957 - val_mean_absolute_error: 1.9957
# Epoch 974/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.2371 - mean_absolute_error: 0.2371 - val_loss: 2.7337 - val_mean_absolute_error: 2.7337
# Epoch 975/1000
# 46/46 [==============================] - 0s 781us/step - loss: 0.3092 - mean_absolute_error: 0.3092 - val_loss: 1.7691 - val_mean_absolute_error: 1.7691
# Epoch 976/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.3856 - mean_absolute_error: 0.3856 - val_loss: 1.7532 - val_mean_absolute_error: 1.7532
# Epoch 977/1000
# 46/46 [==============================] - 0s 564us/step - loss: 0.3045 - mean_absolute_error: 0.3045 - val_loss: 3.0412 - val_mean_absolute_error: 3.0412
# Epoch 978/1000
# 46/46 [==============================] - 0s 520us/step - loss: 0.5110 - mean_absolute_error: 0.5110 - val_loss: 2.5241 - val_mean_absolute_error: 2.5241
# Epoch 979/1000
# 46/46 [==============================] - 0s 607us/step - loss: 0.2484 - mean_absolute_error: 0.2484 - val_loss: 1.4107 - val_mean_absolute_error: 1.4107
# Epoch 980/1000
# 46/46 [==============================] - 0s 564us/step - loss: 0.4613 - mean_absolute_error: 0.4613 - val_loss: 2.1894 - val_mean_absolute_error: 2.1894
# Epoch 981/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.2871 - mean_absolute_error: 0.2871 - val_loss: 2.4168 - val_mean_absolute_error: 2.4168
# Epoch 982/1000
# 46/46 [==============================] - 0s 477us/step - loss: 0.1984 - mean_absolute_error: 0.1984 - val_loss: 1.7674 - val_mean_absolute_error: 1.7674
# Epoch 983/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.3350 - mean_absolute_error: 0.3350 - val_loss: 2.5290 - val_mean_absolute_error: 2.5290
# Epoch 984/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.2623 - mean_absolute_error: 0.2623 - val_loss: 2.7965 - val_mean_absolute_error: 2.7965
# Epoch 985/1000
# 46/46 [==============================] - 0s 412us/step - loss: 0.2606 - mean_absolute_error: 0.2606 - val_loss: 1.6773 - val_mean_absolute_error: 1.6773
# Epoch 986/1000
# 46/46 [==============================] - 0s 542us/step - loss: 0.3299 - mean_absolute_error: 0.3299 - val_loss: 2.0103 - val_mean_absolute_error: 2.0103
# Epoch 987/1000
# 46/46 [==============================] - 0s 520us/step - loss: 0.1652 - mean_absolute_error: 0.1652 - val_loss: 2.2131 - val_mean_absolute_error: 2.2131
# Epoch 988/1000
# 46/46 [==============================] - 0s 607us/step - loss: 0.2069 - mean_absolute_error: 0.2069 - val_loss: 1.5216 - val_mean_absolute_error: 1.5216
# Epoch 989/1000
# 46/46 [==============================] - 0s 585us/step - loss: 0.3216 - mean_absolute_error: 0.3216 - val_loss: 1.9763 - val_mean_absolute_error: 1.9763
# Epoch 990/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.3016 - mean_absolute_error: 0.3016 - val_loss: 2.7496 - val_mean_absolute_error: 2.7496
# Epoch 991/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.3758 - mean_absolute_error: 0.3758 - val_loss: 1.7392 - val_mean_absolute_error: 1.7392
# Epoch 992/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.2100 - mean_absolute_error: 0.2100 - val_loss: 1.8342 - val_mean_absolute_error: 1.8342
# Epoch 993/1000
# 46/46 [==============================] - 0s 651us/step - loss: 0.1753 - mean_absolute_error: 0.1753 - val_loss: 1.9123 - val_mean_absolute_error: 1.9123
# Epoch 994/1000
# 46/46 [==============================] - 0s 542us/step - loss: 0.1430 - mean_absolute_error: 0.1430 - val_loss: 2.3739 - val_mean_absolute_error: 2.3739
# Epoch 995/1000
# 46/46 [==============================] - 0s 455us/step - loss: 0.1825 - mean_absolute_error: 0.1825 - val_loss: 1.9983 - val_mean_absolute_error: 1.9983
# Epoch 996/1000
# 46/46 [==============================] - 0s 607us/step - loss: 0.2232 - mean_absolute_error: 0.2232 - val_loss: 2.3021 - val_mean_absolute_error: 2.3021
# Epoch 997/1000
# 46/46 [==============================] - 0s 521us/step - loss: 0.1768 - mean_absolute_error: 0.1768 - val_loss: 2.4545 - val_mean_absolute_error: 2.4545
# Epoch 998/1000
# 46/46 [==============================] - 0s 499us/step - loss: 0.2180 - mean_absolute_error: 0.2180 - val_loss: 1.4973 - val_mean_absolute_error: 1.4973
# Epoch 999/1000
# 46/46 [==============================] - 0s 824us/step - loss: 0.4336 - mean_absolute_error: 0.4336 - val_loss: 2.2344 - val_mean_absolute_error: 2.2344
# Epoch 1000/1000
# 46/46 [==============================] - 0s 629us/step - loss: 0.2471 - mean_absolute_error: 0.2471 - val_loss: 3.7346 - val_mean_absolute_error: 3.7346

# %%
predictions = NN_model.predict(X_test)

# %%
import sklearn.metrics as metrics
metrics.explained_variance_score(y_test, predictions)
# Out:
# 0.9814026015948297

# %%
predictions
# Out:
# array([[ 0.13663755],
#        [ 0.14261046],
#        [ 0.16209511],
#        [ 0.18309559],
#        [ 0.20207587],
#        [ 0.26218423],
#        [ 0.32516557],
#        [ 0.40721065],
#        [ 0.6285164 ],
#        [ 1.014555  ],
#        [ 1.0932261 ],
#        [ 1.6719658 ],
#        [ 2.2518427 ],
#        [ 3.4606133 ],
#        [ 4.633247  ],
#        [ 5.731708  ],
#        [ 7.1075883 ],
#        [ 9.27016   ],
#        [10.445236  ],
#        [14.425582  ],
#        [19.812534  ],
#        [32.08703   ]], dtype=float32)

# %%
y_test
# Out:
#     crack_growth_rate
# 21             0.0761
# 22             0.1150
# 23             0.1730
# 24             0.1890
# 25             0.2430
# 26             0.2800
# 27             0.3940
# 28             0.4880
# 29             0.5740
# 30             0.7910
# 31             0.9800
# 32             1.4800
# 33             1.9700
# 34             2.9700
# 35             3.8800
# 36             5.7600
# 37             7.6600
# 38             9.6500
# 39            11.3000
# 40            17.4000
# 41            19.0000
# 42            28.7000

# %%
y_test.shape
# Out:
# (22, 1)

# %%
actual_y = y_test.values
error =0
for i in range(22):
    error += abs((actual_y[i])-(predictions[i]))

# %%
error/22
# Out:
# array([0.51870799])

# %%
data.mean()
# Out:
# R                    0.197403
# delta_K              5.721191
# crack_growth_rate    4.147470
# dtype: float64

# %%
percentage_error = 0
total_error = 0
total_per_error = 0
for i in range(22):
    per_error = ((abs(actual_y[i]-predictions[i]))/(actual_y[i]) )* 100
    percentage_error += per_error

# %%
percentage_error / 22
# Out:
# array([15.23252581])

# %%
fig = plt.figure(figsize=(10,10))
plt.yscale('log')
ax0= fig.add_subplot(111)
line1=ax0.scatter(X_test.delta_K, predictions, c= 'b',marker ='.',label='Neural network pedictions')
line2=ax0.scatter(X_test.delta_K,y_test, c= 'r' , marker ='.',label='Experimental data')
ax0.set_xlabel('Stress Intensity factor range',fontsize =20)
ax0.set_ylabel('Crack growth rate(mm/cycle)',fontsize =20)
ax0.set_title('R =0.1')
ax0.legend(fontsize=18)
plt.savefig('NN_on_unseen_R.png')
#ax0.set_facecolor('#82cafc')
# Out:
# C:\Users\vinod khoja\AppData\Local\conda\conda\envs\keras-gpu\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
my_X = data.drop(['crack_growth_rate'],axis=1)
y=data.drop(['R','delta_K'],axis=1)
#predicting_on_complete_dataset = NN_model.predict(my_X)

# %%
#predicting_on_complete_dataset.shape
my_y = y.values

# %%
percentage_error = 0
total_error = 0
total_per_error = 0
for i in range(77):
    per_error = ((abs(my_y[i]-predicted_dadN[i]))/(my_y[i]) )* 100
    percentage_error += per_error

# %%
percentage_error/77
# Out:
# array([10.27821042])

# %%
model_json = NN_model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
NN_model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1bc4521e8f48> in <module>
# ----> 1 model_json = NN_model.to_json()
#       2 with open("model.json", "w") as json_file:
#       3     json_file.write(model_json)
#       4 NN_model.save_weights("model.h5")
#       5 print("Saved model to disk")
#
# NameError: name 'NN_model' is not defined

# %%
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model

loaded_model.load_weights("model.h5")
print("Loaded model from disk")

loaded_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
# Out:
# WARNING:tensorflow:From C:\Users\vinod khoja\AppData\Local\conda\conda\envs\keras-gpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Loaded model from disk

# %%
complete_features = data.drop("crack_growth_rate", axis = 1)

# %%
predicted_dadN = loaded_model.predict(complete_features)

# %%
original_data["predicted_crack_growth_rate"] = predicted_dadN * (10**(-5))
#Now original data contains predicted and experimental values

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection = '3d')

#plt.gca().patch.set_facecolor('white')
ax.w_xaxis.set_pane_color((0.8, 0.8, 0.8, 1.0))
ax.w_yaxis.set_pane_color((0.8, 0.8, 0.8, 1.0))
ax.w_zaxis.set_pane_color((0.8, 0.8, 0.8, 1.0))

X = data['R'].values
Y = data['delta_K'].values
Z = data['crack_growth_rate'].values
ax.scatter(X,Y,Z, c = 'b' , marker = '.')
ax.set_xlabel('R(stress ratio)',fontsize =20)
ax.set_ylabel('Stress Intensity factor range',fontsize =16)
ax.set_zlabel('crack growth rate(mm/cycle)',fontsize =16)
#ax.grid(False)
plt.savefig('training_data.png')
plt.show()

# %%
subdf_0 = data.loc[data['R'] == 0]
subdf_1 = data.loc[data['R'] == 0.1]
subdf_3 = data.loc[data['R'] == 0.3]
subdf_5 = data.loc[data['R'] == 0.5]

# %%
## predict for R = 0
r0_data_predictions = loaded_model.predict(subdf_0.drop("crack_growth_rate",axis = 1))

# %%
# one hell of a result/.///chill

# %%
#fitting the parislaw
from scipy.optimize import curve_fit 
indexes = np.sort(np.random.choice(21, size=15, replace=False))
paris_y = (subdf_0.crack_growth_rate.values[indexes])* (10**(-5))

paris_x = subdf_0.delta_K.values[indexes]
  
def test(paris_x, C, m): 
    return C * (paris_x ** (m)) 
  
param, param_cov = curve_fit(test, paris_x, paris_y) 
  
print("funcion coefficients:") 
print(param)
# Out:
# funcion coefficients:
# [1.98424357e-10 5.64557757e+00]

# %%
paris_x_test = subdf_0.delta_K.values
paris_predictions = param[0] * ((paris_x_test)**(param[1]))

# %%
paris_predictions
# Out:
# array([1.72237886e-07, 1.88217577e-07, 2.13791122e-07, 2.42841667e-07,
#        2.80261605e-07, 3.36208056e-07, 3.88019065e-07, 6.68320397e-07,
#        1.83929288e-06, 3.27796539e-06, 4.97061701e-06, 6.07233904e-06,
#        1.10208382e-05, 1.25182917e-05, 2.44354122e-05, 3.20325603e-05,
#        5.60588050e-05, 1.00135155e-04, 1.75241063e-04, 2.29726169e-04,
#        3.61263252e-04])

# %%
fig = plt.figure(figsize=(10,10))
plt.yscale('log')
ax0= fig.add_subplot(111)
line1=ax0.scatter(subdf_0.delta_K, r0_data_predictions, c= 'b',marker ='.',label='Neural network pedictions')
line2=ax0.scatter(subdf_0.delta_K,subdf_0.crack_growth_rate, c= 'r' , marker ='.',label='Experimental data')
ax0.set_xlabel('Stress Intensity factor range',fontsize =20)
ax0.set_ylabel('Crack growth rate(mm/cycle)',fontsize =20)

ax0.legend(fontsize=18)
#ax0.set_facecolor('#82cafc')
plt.savefig('NN_with_exp_data.png')
# ax0.scatter(subdf_1.delta_K,subdf_1.crack_growth_rate, c= 'b' , marker ='.')
# ax0.scatter(subdf_3.delta_K,subdf_3.crack_growth_rate, c= 'b' , marker ='o')
# ax0.scatter(subdf_5.delta_K,subdf_5.crack_growth_rate, c= 'r' , marker ='o')
# Out:
# C:\Users\vinod khoja\AppData\Local\conda\conda\envs\keras-gpu\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#plotting paris_predictions with experimental_data
fig = plt.figure(figsize=(10,10))
plt.yscale('log')
#plt.rcParams.update({'font.size':15})

ax0= fig.add_subplot(111)
ax0.scatter(subdf_0.delta_K, paris_predictions*(10**5), c= 'b',marker ='.',label='Paris law results')
ax0.scatter(subdf_0.delta_K,subdf_0.crack_growth_rate, c= 'r' , marker ='.',label='Experimental data')
ax0.set_xlabel('Stress Intensity factor range',fontsize=20)
ax0.set_ylabel('Crack growth rate(mm/cycle)',fontsize =20)
ax0.legend(fontsize=18)
plt.savefig('paris_law_with_exp_data.png')
# Out:
# C:\Users\vinod khoja\AppData\Local\conda\conda\envs\keras-gpu\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
# calculating the mean squared error for both Paris and Sequenial Neural Network models
paris_error = 0
NN_error = 0
experimental_dadN = subdf_0.crack_growth_rate.values
for i in range(20):
    paris_error += abs((experimental_dadN[i] * (10 **(-5)))**(2) - (paris_predictions[i])**(2))
    NN_error+=abs((experimental_dadN[i] * (10**(-5)))**(2) - (r0_data_predictions[i] * (10 ** (-5)))**(2))
print("MSE of the Paris model is :")
print(paris_error/21)

##as paris model's MSE is calculated completely on training_data itself it is likely to show better MSE than teh actual.
## train on only 15 points and then test on all 21 points to achieve a clear comparison.
print("MSW of the Neural Network model is :")
print(NN_error/21)
# Out:
# MSE of the Paris model is :
# 8.042189074573223e-10
# MSW of the Neural Network model is :
# [1.6599495e-10]

# %%
subdf_1.shape[0]
# Out:
# 22

# %%
Rs = [0,0.1,0.3,0.5]
from scipy.optimize import curve_fit

for r in Rs:
    subdf_any = data.loc[data['R'] == r]
    nn_predictions = NN_model.predict(subdf_any.drop("crack_growth_rate",axis = 1))
    indexes = np.sort(np.random.choice(subdf_any.shape[0], size=14, replace=False))
    paris_y = (subdf_any.crack_growth_rate.values[indexes])* (10**(-5))
    paris_x = subdf_any.delta_K.values[indexes]
    def test(paris_x, C, m): 
        return C * (paris_x ** (m))
    param, param_cov = curve_fit(test, paris_x, paris_y)
    print(" funcion coefficients for R = " + str(r) +":") 
    print(param)
    paris_x_test = subdf_any.delta_K.values
    paris_predictions1 = param[0] * ((paris_x_test)**(param[1]))
    paris_error = 0
    NN_error = 0
    experimental_dadN = subdf_any.crack_growth_rate.values
    for i in range(subdf_any.shape[0]):
        paris_error += ((experimental_dadN[i] * (10 **(-5))) - (paris_predictions1[i]))**2
        NN_error+=((experimental_dadN[i] * (10**(-5))) - (nn_predictions[i] * (10 ** (-5))))**2
    print("MSE of the Paris model for R = " + str(r) + " is :")
    print(paris_error/subdf_any.shape[0])
    print("MSW of the Neural Network model for R = " + str(r) + "is :")
    print(NN_error/subdf_any.shape[0])
# Out:
#  funcion coefficients for R = 0:
# [7.80051803e-11 6.00414583e+00]
# MSE of the Paris model for R = 0 is :
# 4.9082523589782183e-11
# MSW of the Neural Network model for R = 0is :
# [1.2452005e-11]
#  funcion coefficients for R = 0.1:
# [8.43508902e-09 4.28370292e+00]
# MSE of the Paris model for R = 0.1 is :
# 8.45763133493784e-11
# MSW of the Neural Network model for R = 0.1is :
# [2.1946324e-10]
#  funcion coefficients for R = 0.3:
# [1.24933028e-08 4.34135694e+00]
# MSE of the Paris model for R = 0.3 is :
# 3.3165045149823595e-11
# MSW of the Neural Network model for R = 0.3is :
# [5.297075e-12]
#  funcion coefficients for R = 0.5:
# [2.74384175e-10 6.81710814e+00]
# MSE of the Paris model for R = 0.5 is :
# 7.595708011945337e-12
# MSW of the Neural Network model for R = 0.5is :
# [4.042171e-10]

# %%
## predict for R = 0.1
r1_data_predictions = loaded_model.predict(subdf_1.drop("crack_growth_rate",axis = 1))
indexes = np.sort(np.random.choice(22, size=15, replace=False))
paris_y = (subdf_1.crack_growth_rate.values[indexes])* (10**(-5))

paris_x = subdf_1.delta_K.values[indexes]
  
def test(paris_x, C, m): 
    return C * (paris_x ** (m)) 
  
param, param_cov = curve_fit(test, paris_x, paris_y) 
  
print(" funcion coefficients:") 
print(param) 

paris_x_test = subdf_1.delta_K.values
paris_predictions1 = param[0] * ((paris_x_test)**(param[1]))
paris_error = 0
NN_error = 0
experimental_dadN = subdf_1.crack_growth_rate.values
for i in range(22):
    paris_error += abs((experimental_dadN[i] * (10 **(-5)))**(2) - (paris_predictions1[i])**(2))
    NN_error+=abs((experimental_dadN[i] * (10**(-5)))**(2) - (r1_data_predictions[i] * (10 ** (-5)))**(2))
print("MSE of the Paris model is :")
print(paris_error/22)

##as paris model's MSE is calculated completely on training_data itself it is likely to show better MSE than teh actual.
## train on only 15 points and then test on all 21 points to achieve a clear comparison.
print("MSW of the Neural Network model is :")
print(NN_error/22)
# Out:
#  funcion coefficients:
# [8.29404654e-09 4.29950662e+00]
# MSE of the Paris model is :
# 1.2703613512923632e-09
# MSW of the Neural Network model is :
# [3.156272e-10]

# %%
subdf_3.shape
# Out:
# (20, 3)

# %%
## predict for R = 0.3
r3_data_predictions = loaded_model.predict(subdf_3.drop("crack_growth_rate",axis = 1))
indexes = np.sort(np.random.choice(20, size=15, replace=False))
paris_y = (subdf_3.crack_growth_rate.values[indexes])* (10**(-5))

paris_x = subdf_3.delta_K.values[indexes]
  
def test(paris_x, C, m): 
    return C * (paris_x ** (m)) 
  
param, param_cov = curve_fit(test, paris_x, paris_y) 
  
print(" funcion coefficients:") 
print(param) 

paris_x_test = subdf_3.delta_K.values
paris_predictions3 = param[0] * ((paris_x_test)**(param[1]))
paris_error = 0
NN_error = 0
experimental_dadN = subdf_3.crack_growth_rate.values
for i in range(20):
    paris_error += abs((experimental_dadN[i] * (10 **(-5)))**(2) - (paris_predictions3[i])**(2))
    NN_error+=abs((experimental_dadN[i] * (10**(-5)))**(2) - (r3_data_predictions[i] * (10 ** (-5)))**(2))
print("MSE of the Paris model is :")
print(paris_error/20)

##as paris model's MSE is calculated completely on training_data itself it is likely to show better MSE than teh actual.
## train on only 15 points and then test on all 21 points to achieve a clear comparison.
print("MSW of the Neural Network model is :")
print(NN_error/20)
# Out:
#  funcion coefficients:
# [1.73419148e-08 4.18327610e+00]
# MSE of the Paris model is :
# 3.688890229109397e-10
# MSW of the Neural Network model is :
# [4.4120457e-10]

# %%
subdf_5.shape
# Out:
# (14, 3)

# %%
## predict for R = 0.3
r5_data_predictions = loaded_model.predict(subdf_5.drop("crack_growth_rate",axis = 1))
indexes = np.sort(np.random.choice(14, size=9, replace=False))
paris_y = (subdf_5.crack_growth_rate.values[indexes])* (10**(-5))

paris_x = subdf_5.delta_K.values[indexes]
  
def test(paris_x, C, m): 
    return C * (paris_x ** (m)) 
  
param, param_cov = curve_fit(test, paris_x, paris_y) 
  
print(" funcion coefficients:") 
print(param) 

paris_x_test = subdf_5.delta_K.values
paris_predictions5 = param[0] * ((paris_x_test)**(param[1]))
paris_error = 0
NN_error = 0
experimental_dadN = subdf_5.crack_growth_rate.values
for i in range(14):
    paris_error += abs((experimental_dadN[i] * (10 **(-5)))**(2) - (paris_predictions5[i])**(2))
    NN_error+=abs((experimental_dadN[i] * (10**(-5)))**(2) - (r5_data_predictions[i] * (10 ** (-5)))**(2))
print("MSE of the Paris model is :")
print(paris_error/14)

##as paris model's MSE is calculated completely on training_data itself it is likely to show better MSE than teh actual.
## train on only 15 points and then test on all 21 points to achieve a clear comparison.
print("MSW of the Neural Network model is :")
print(NN_error/14)
# Out:
#  funcion coefficients:
# [4.68317547e-10 6.54928019e+00]
# MSE of the Paris model is :
# 1.1520674213275249e-10
# MSW of the Neural Network model is :
# [4.2585763e-10]

# %%
## fatigue life calculation(in cycles)
# check the units and dimensions before calculating
a = 0.5
if(R==0):
    delta_sigma = 80 #in MPa
else if(R == 0.1):
    delta_sigma = 77
else if(R == 0.3):
    delta_sigma = 53
else if(R == 0.5 ):
    delta_sigma = 46
width = 7.2 #in mm
number_of_cycles = 0
while( a < 5 ):
    temp_df = pd.DataFrame(data=None, columns=data.columns)
    temp_df = temp_df.drop("crack_growth_rate",axis = 1)
    
    # formula from TL_Anderson for mode-1 laoding
    Y = (width/a) * (1 /(np.pi)) * (np.tan ( (np.pi)/(width/a)))#calculating geometric factor
    
    temp_delta_k = Y * delta_sigma * np.sqrt( np.pi * a) #calculating delta k for this cycle
    
    new_row = {'R':R, 'delta_K':temp_delta_k}
    temp_df = temp_df.append(new_row, ignore_index=True)
    da = loaded_model.predict(temp_df)
    a += da
    number_of_cycles+=1
fatigue_life = number_of_cycles
